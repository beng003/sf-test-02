# %% [markdown]
# # 垂直联邦XGB (MPC XGBoost)
#
# > 以下代码仅供演示。出于系统安全考虑，请 **不要** 直接用于生产。

# %%
from sklearn.metrics import roc_auc_score

import secretflow as sf
from secretflow.data import FedNdarray, PartitionWay
from secretflow.device.driver import reveal
from secretflow.ml.boost.ss_xgb_v import Xgb
import pprint

pp = pprint.PrettyPrinter(depth=4)

# Check the version of your SecretFlow
print('The version of SecretFlow: {}'.format(sf.__version__))
# Out:
# The version of SecretFlow: 1.7.0b0

# %%
# process_utils.py
import psutil
import os
import platform


def find_process_by_port(port):
    for proc in psutil.process_iter(["pid", "name"]):
        try:
            connections = proc.connections(kind="inet")
            for conn in connections:
                if conn.laddr.port == port:
                    return proc.pid
        except (psutil.AccessDenied, psutil.NoSuchProcess):
            continue
    return None


def kill_process(pid):
    try:
        if platform.system() == "Windows":
            os.system(f"taskkill /PID {pid} /F")
        else:
            os.system(f"kill -9 {pid}")
        print(f"Process with PID {pid} has been terminated.")
    except Exception as e:
        print(f"Error terminating process with PID {pid}: {e}")


def kill_port_process(port: int):
    pid = find_process_by_port(port)

    if pid:
        print(f"Process found using port {port}: PID {pid}")
        kill_process(pid)
    else:
        print(f"No process found using port {port}")


pyu_port = 16307
spu_port = 11666

kill_port_process(port=pyu_port)
kill_port_process(port=spu_port)

import secretflow as sf

# Check the version of your SecretFlow
print("The version of SecretFlow: {}".format(sf.__version__))

# In case you have a running secretflow runtime already.
sf.shutdown()

pyu_port = 16307
spu_port = 11666


cluster_config = {
    "parties": {
        "alice": {
            # replace with alice's real address.
            "address": "ecm-01:" + str(pyu_port),
            "listen_addr": "0.0.0.0:" + str(pyu_port),
        },
        "bob": {
            # replace with bob's real address.
            "address": "ecm-02:" + str(pyu_port),
            "listen_addr": "0.0.0.0:" + str(pyu_port),
        },
    },
    "self_party": "bob",
}

tls_config = {
    "ca_cert": "/home/beng003/certificate/alice_ca.crt",
    "cert": "/home/beng003/certificate/bob_server_cert.crt",
    "key": "/home/beng003/certificate/bob_server_key.key",
}


sf.init(address="ecm-02:6379", cluster_config=cluster_config, tls_config=tls_config)
alice = sf.PYU("alice")
bob = sf.PYU("bob")
print("Alice and Bob are ready to go!")

import spu

cluster_def = {
    "nodes": [
        {
            "party": "alice",
            # The address for other peers.
            "address": "ecm-01:" + str(spu_port),
            # The listen address of this node.
            # Optional. Address will be used if listen_address is empty.
            "listen_address": "0.0.0.0:" + str(spu_port),
        },
        {
            "party": "bob",
            "address": "ecm-02:" + str(spu_port),
            "listen_address": "0.0.0.0:" + str(spu_port),
        },
    ],
    "runtime_config": {
        "protocol": spu.spu_pb2.SEMI2K,
        "field": spu.spu_pb2.FM128,
        "sigmoid_mode": spu.spu_pb2.RuntimeConfig.SIGMOID_REAL,
    },
}

link_desc = {
    "recv_timeout_ms": 6000,
}

spu_device = sf.SPU(cluster_def=cluster_def, link_desc=link_desc)
print("*****************************************************Bob SPU")
# Out:
# /tmp/ipykernel_1806041/3673316979.py:10: DeprecationWarning: connections() is deprecated and will be removed; use net_connections() instead
#   connections = proc.connections(kind="inet")
# 2024-08-03 16:37:46,446	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: ecm-02:6379...
# 2024-08-03 16:37:46,455	INFO worker.py:1724 -- Connected to Ray cluster.
# 2024-08-03 16:37:46.481 INFO api.py:233 [bob] -- [Anonymous_job] Started rayfed with {'CLUSTER_ADDRESSES': {'alice': 'ecm-01:16307', 'bob': '0.0.0.0:16307'}, 'CURRENT_PARTY_NAME': 'bob', 'TLS_CONFIG': {'ca_cert': '/home/beng003/certificate/alice_ca.crt', 'cert': '/home/beng003/certificate/bob_server_cert.crt', 'key': '/home/beng003/certificate/bob_server_key.key'}}
# No process found using port 16307
# No process found using port 11666
# The version of SecretFlow: 1.7.0b0
# 2024-08-03 16:37:47.478 INFO barriers.py:284 [bob] -- [Anonymous_job] Succeeded to create receiver proxy actor.
# (ReceiverProxyActor pid=1806172) 2024-08-03 16:37:47.473 INFO grpc_proxy.py:359 [bob] -- [Anonymous_job] ReceiverProxy binding port 16307, options: (('grpc.enable_retries', 1), ('grpc.so_reuseport', 0), ('grpc.max_send_message_length', 524288000), ('grpc.max_receive_message_length', 524288000), ('grpc.service_config', '{"methodConfig": [{"name": [{"service": "GrpcService"}], "retryPolicy": {"maxAttempts": 5, "initialBackoff": "5s", "maxBackoff": "30s", "backoffMultiplier": 2, "retryableStatusCodes": ["UNAVAILABLE"]}}]}'))...
# (ReceiverProxyActor pid=1806172) 2024-08-03 16:37:47.477 INFO grpc_proxy.py:379 [bob] -- [Anonymous_job] Successfully start Grpc service with credentials.
# 2024-08-03 16:37:48.419 INFO barriers.py:333 [bob] -- [Anonymous_job] SenderProxyActor has successfully created.
# 2024-08-03 16:37:48.420 INFO barriers.py:520 [bob] -- [Anonymous_job] Try ping ['alice'] at 0 attemp, up to 3600 attemps.
# 2024-08-03 16:37:51.425 INFO barriers.py:520 [bob] -- [Anonymous_job] Try ping ['alice'] at 1 attemp, up to 3600 attemps.
# 2024-08-03 16:37:54.428 INFO barriers.py:520 [bob] -- [Anonymous_job] Try ping ['alice'] at 2 attemp, up to 3600 attemps.
# Alice and Bob are ready to go!
# *****************************************************Bob SPU

# %% [markdown]
# ## 数据准备
#
# 我们将准备一个垂直数据集。

# %%
from sklearn.datasets import load_breast_cancer

ds = load_breast_cancer()
x, y = ds['data'], ds['target']

v_data = FedNdarray(
    {
        alice: (alice(lambda: x[:, :15])()),
        bob: (bob(lambda: x[:, 15:])()),
    },
    partition_way=PartitionWay.VERTICAL,
)
label_data = FedNdarray(
    {alice: (alice(lambda: y)())},
    partition_way=PartitionWay.VERTICAL,
)

# %%
import pandas as pd

df = pd.DataFrame(ds['data'], columns=ds["feature_names"])
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# ### 参数准备

# %%
params = {
    "num_boost_round": 10,  # Number of boosting iterations, default is 10
    "max_depth": 5,  # Maximum depth of a tree, default is 5
    "learning_rate": 0.3,  # Step size shrinkage, default is 0.3
    "objective": "logistic",  # Learning objective, default is 'logistic'
    "reg_lambda": 0.1,  # L2 regularization term, default is 0.1
    "subsample": 1,  # Subsample ratio of the training instances, default is 1
    "colsample_by_tree": 1,  # Subsample ratio of columns, default is 1
    "sketch_eps": 0.1,  # Number of bins for sketching, default is 0.1
    "base_score": 0,  # Initial prediction score, default is 0
    "seed": 42,  # Pseudorandom number generator seed, default is 42
}
pp.pprint(params)
# Out:
# {'base_score': 0,
#  'colsample_by_tree': 1,
#  'learning_rate': 0.3,
#  'max_depth': 5,
#  'num_boost_round': 10,
#  'objective': 'logistic',
#  'reg_lambda': 0.1,
#  'seed': 42,
#  'sketch_eps': 0.1,
#  'subsample': 1}

# %% [markdown]
# ## 运行 Xgb
#
# 我们使用 spu 设备创建一个 Xgb 对象，并拟合数据。

# %%
xgb = Xgb(spu_device)
model = xgb.train(params, v_data, label_data)
# Out:
# 2024-08-03 16:38:25.267 INFO proxy.py:180 [bob] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party alice.
# 2024-08-03 16:38:25.268 INFO proxy.py:180 [bob] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party bob.
# 2024-08-03 16:38:25.306 INFO booster.py:167 [bob] -- [Anonymous_job] fragment_count 1
# 2024-08-03 16:38:26.953 INFO booster.py:185 [bob] -- [Anonymous_job] prepare time 4.175525903701782s
# 2024-08-03 16:38:27.141 INFO booster.py:198 [bob] -- [Anonymous_job] global_setup time 0.18709659576416016s
# 2024-08-03 16:38:33.376 INFO booster.py:217 [bob] -- [Anonymous_job] build & infeed bucket_map fragments [0, 0]
# 2024-08-03 16:38:33.377 INFO booster.py:220 [bob] -- [Anonymous_job] build & infeed bucket_map time 6.234294414520264s
# 2024-08-03 16:38:33.515 INFO booster.py:233 [bob] -- [Anonymous_job] init_pred time 0.1380321979522705s
# 2024-08-03 16:38:33.571 INFO booster.py:375 [bob] -- [Anonymous_job] epoch 0 tree_setup time 0.05512189865112305s
# 2024-08-03 16:38:36.335 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 2.760763168334961s
# 2024-08-03 16:38:37.796 INFO booster.py:486 [bob] -- [Anonymous_job] level 0 time 4.221945524215698s
# 2024-08-03 16:38:42.771 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.973941802978516s
# 2024-08-03 16:38:45.683 INFO booster.py:486 [bob] -- [Anonymous_job] level 1 time 7.885941505432129s
# 2024-08-03 16:38:55.597 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.913377046585083s
# 2024-08-03 16:39:00.426 INFO booster.py:486 [bob] -- [Anonymous_job] level 2 time 14.74228024482727s
# 2024-08-03 16:39:20.189 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.76205325126648s
# 2024-08-03 16:39:29.626 INFO booster.py:486 [bob] -- [Anonymous_job] level 3 time 29.198264122009277s
# 2024-08-03 16:40:09.832 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.205039978027344s
# 2024-08-03 16:40:28.954 INFO booster.py:486 [bob] -- [Anonymous_job] level 4 time 59.32712769508362s
# 2024-08-03 16:40:29.299 INFO xla_bridge.py:863 [bob] -- [Anonymous_job] Unable to initialize backend 'cuda':
# 2024-08-03 16:40:29.301 INFO xla_bridge.py:863 [bob] -- [Anonymous_job] Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2024-08-03 16:40:29.303 INFO xla_bridge.py:863 [bob] -- [Anonymous_job] Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2024-08-03 16:40:29.583 WARNING callback.py:455 [bob] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:40:30.690 INFO booster.py:392 [bob] -- [Anonymous_job] epoch 0 time 117.11752271652222s
# 2024-08-03 16:40:31.255 INFO booster.py:375 [bob] -- [Anonymous_job] epoch 1 tree_setup time 0.5642027854919434s
# 2024-08-03 16:40:36.471 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.21357274055481s
# 2024-08-03 16:40:38.306 INFO booster.py:486 [bob] -- [Anonymous_job] level 0 time 7.048418760299683s
# 2024-08-03 16:40:43.468 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.161218643188477s
# 2024-08-03 16:40:45.970 INFO booster.py:486 [bob] -- [Anonymous_job] level 1 time 7
INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 20.480794191360474s
# 2024-08-03 16:57:29.265 INFO booster.py:486 [bob] -- [Anonymous_job] level 3 time 29.612849473953247s
# 2024-08-03 16:58:09.747 INFO booster.py:426 [bob] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.480345010757446s
# 2024-08-03 16:58:27.915 INFO booster.py:486 [bob] -- [Anonymous_job] level 4 time 58.6491174697876s
# 2024-08-03 16:58:28.531 WARNING callback.py:455 [bob] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:58:28.606 INFO booster.py:392 [bob] -- [Anonymous_job] epoch 9 time 118.06346678733826s
# (_run pid=1806360) INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda':
# (_run pid=1806360) INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# (_run pid=1806360) INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# (_run pid=1806360) [2024-08-03 16:38:27.285] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7
# (SPURuntime(device_id=None, party=bob) pid=1806286) 2024-08-03 16:38:33.618 [info] [thread_pool.cc:ThreadPool:30] Create a fixed thread pool with size 7
# (XgbTreeWorker pid=1806502) [2024-08-03 16:40:29.589] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7
# (XgbTreeWorker pid=1809610) [2024-08-03 16:59:47.823] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7

# %% [markdown]
# ## 模型评估
#
# 现在我们可以将模型输出与真实标签进行比较。

# %%
yhat = model.predict(v_data)
yhat = reveal(yhat)
print(f"auc: {roc_auc_score(y, yhat)}")
# Out:
# 2024-08-03 16:59:46.025 INFO proxy.py:180 [bob] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party alice.
# 2024-08-03 16:59:46.026 INFO proxy.py:180 [bob] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party bob.
# auc: 1.0

# %% [markdown]
# ## 模型权重
#
# 现在我们可以将模型输出与真实标签进行比较。

# %%
a=sf.reveal(model.get_weights())
a
# Out:
# [array([[ 0.591123  ],
#         [ 0.3934378 ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.5492958 ],
#         [-0.2727273 ],
#         [ 0.27272728],
#         [-0.44680843],
#         [ 0.5555502 ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.42856592],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.58973515],
#         [ 0.54545456],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.5624961 ],
#         [ 0.        ],
#         [-0.5985111 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.3981441 ],
#         [ 0.        ],
#         [-0.10535111],
#         [ 0.37898457],
#         [ 0.2834919 ],
#         [-0.5448195 ],
#         [-0.76084554],
#         [-0.38050643],
#         [ 0.36560106],
#         [ 0.        ],
#         [-0.2921255 ],
#         [ 0.        ],
#         [ 0.29212546],
#         [ 0.        ],
#         [-0.38877958],
#         [ 0.        ],
#         [ 0.34588653],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.37891412],
#         [ 0.        ],
#         [ 0.26710364],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.39509282]], dtype=float32),
#  array([[ 0.26718974],
#         [ 0.3500401 ],
#         [ 0.2988608 ],
#         [-0.37034643],
#         [ 0.        ],
#         [ 0.209736  ],
#         [ 0.        ],
#         [-0.32609916],
#         [ 0.26627415],
#         [ 0.        ],
#         [-1.0293983 ],
#         [-0.41387975],
#         [ 0.        ],
#         [-0.21890049],
#         [ 0.3311882 ],
#         [ 0.        ],
#         [ 0.35158712],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.25373688],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.51601195],
#         [ 0.        ],
#         [ 0.36787134],
#         [ 0.        ],
#         [-0.3201239 ],
#         [ 0.        ],
#         [-0.27821127],
#         [ 0.3063407 ],
#         [-0.8623687 ],
#         [-0.35644495]], dtype=float32),
#  array([[ 0.3332088 ],
#         [ 0.        ],
#         [ 0.33406582],
#         [-0.03938682],
#         [-0.38617912],
#         [ 0.        ],
#         [ 0.29911625],
#         [ 0.        ],
#         [ 0.27231467],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.32112342],
#         [ 0.        ],
#         [ 0.17797159],
#         [ 0.        ],
#         [ 0.3230602 ],
#         [ 0.        ],
#         [-0.22463126],
#         [ 0.        ],
#         [-0.34218898],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.32184315],
#         [ 0.        ],
#         [-0.29407328],
#         [ 0.        ],
#         [ 0.24765515],
#         [-0.30172214],
#         [ 0.        ],
#         [-0.34061396]], dtype=float32),
#  array([[ 0.32236063],
#         [ 0.        ],
#         [ 0.31805664],
#         [-0.11591591],
#         [ 0.        ],
#         [-0.29521984],
#         [ 0.24576254],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.19560583],
#         [ 0.        ],
#         [-0.5096166 ],
#         [ 0.33299682],
#         [ 0.        ],
#         [ 0.2488591 ],
#         [-0.23836315],
#         [ 0.30302256],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.2897985 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.2214303 ],
#         [ 0.        ],
#         [-0.23860018],
#         [ 0.        ],
#         [ 0.28194898],
#         [ 0.2783103 ],
#         [-0.26931763],
#         [ 0.12951061],
#         [-0.325354  ]], dtype=float32),
#  array([[ 0.31500655],
#         [ 0.        ],
#         [ 0.30796462],
#         [-0.03488323],
#         [-0.28055716],
#         [ 0.11507557],
#         [ 0.27480602],
#         [-0.17984855],
#         [-0.032153  ],
#         [ 0.24848664],
#         [-0.23216924],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.25591332],
#         [ 0.19951227],
#         [-0.3240342 ],
#         [ 0.        ],
#         [ 0.25093687],
#         [ 0.        ],
#         [-0.1266432 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.24221128],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.3130868 ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.31030503],
#         [ 0.08196747],
#         [ 0.        ],
#         [-0.14543784],
#         [ 0.30508298],
#         [ 0.        ],
#         [ 0.09824237],
#         [-1.0739944 ],
#         [ 0.28366417],
#         [ 0.        ],
#         [ 0.25681895],
#         [-0.1030097 ],
#         [ 0.23277362],
#         [-0.242273  ],
#         [ 0.0236219 ],
#         [-0.30008656],
#         [ 0.23082122],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.11732116],
#         [-0.22810535],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.30813575],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30817574],
#         [ 0.        ],
#         [-0.22880454],
#         [ 0.2154033 ],
#         [ 0.28733182],
#         [ 0.        ],
#         [-0.43049678],
#         [ 0.08039601],
#         [ 0.20137362],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.0937544 ],
#         [-0.2583147 ],
#         [ 0.        ],
#         [ 0.13537171],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.37900987],
#         [ 0.29787055],
#         [ 0.        ],
#         [ 0.19497898],
#         [-0.19938886],
#         [ 0.        ],
#         [-0.18202381],
#         [ 0.        ],
#         [ 0.2048984 ],
#         [ 0.17127188],
#         [-0.12711516],
#         [-0.30196753],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30403554],
#         [ 0.        ],
#         [-0.2414328 ],
#         [ 0.21938673],
#         [ 0.07624964],
#         [-0.23797469],
#         [ 0.242425  ],
#         [-0.13473305],
#         [ 0.20791271],
#         [-0.07837531],
#         [-0.1877125 ],
#         [ 0.        ],
#         [ 0.20785634],
#         [ 0.        ],
#         [ 0.1441516 ],
#         [-0.2899298 ],
#         [ 0.        ],
#         [ 0.21458283],
#         [ 0.        ],
#         [-0.09764111],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.20386623],
#         [ 0.        ],
#         [-0.3013265 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30259073],
#         [ 0.00066423],
#         [-0.18387267],
#         [ 0.18892273],
#         [ 0.2745835 ],
#         [ 0.        ],
#         [-0.3629639 ],
#         [ 0.18248284],
#         [ 0.23308651],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.1625843 ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.2600273 ],
#         [ 0.24127562],
#         [-0.07357024],
#         [-0.28496355],
#         [ 0.11374386],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.26348457],
#         [ 0.        ],
#         [ 0.20077303],
#         [ 0.        ],
#         [-0.20375805],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.11340426],
#         [-0.07324639],
#         [-0.30070984]], dtype=float32)]

# %%
import numpy as np

pd.DataFrame(np.array(a).reshape(-1, 32))
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.591123  0.393438  0.000000 -0.428566  0.549296 -0.272727  0.272727
# 1  0.398144  0.000000 -0.105351  0.378985  0.283492 -0.544819 -0.760846
# 2  0.267190  0.350040  0.298861 -0.370346  0.000000  0.209736  0.000000
# 3  0.333209  0.000000  0.334066 -0.039387 -0.386179  0.000000  0.299116
# 4  0.322361  0.000000  0.318057 -0.115916  0.000000 -0.295220  0.245763
# 5  0.315007  0.000000  0.307965 -0.034883 -0.280557  0.115076  0.274806
# 6  0.310305  0.081967  0.000000 -0.145438  0.305083  0.000000  0.098242
# 7  0.308176  0.000000 -0.228805  0.215403  0.287332  0.000000 -0.430497
# 8  0.304036  0.000000 -0.241433  0.219387  0.076250 -0.237975  0.242425
# 9  0.302591  0.000664 -0.183873  0.188923  0.274583  0.000000 -0.362964
#
#          7         8         9   ...        22        23        24        25  \
# 0 -0.446808  0.555550  0.000000  ...  0.000000 -0.562496  0.000000 -0.598511
# 1 -0.380506  0.365601  0.000000  ...  0.267104  0.000000  0.000000  0.000000
# 2 -0.326099  0.266274  0.000000  ... -0.516012  0.000000  0.367871  0.000000
# 3  0.000000  0.272315  0.000000  ...  0.000000  0.000000  0.321843  0.000000
# 4  0.000000  0.000000  0.195606  ...  0.000000  0.221430  0.000000 -0.238600
# 5 -0.179849 -0.032153  0.248487  ...  0.000000 -0.242211  0.000000  0.000000
# 6 -1.073994  0.283664  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 7  0.080396  0.201374  0.000000  ...  0.194979 -0.199389  0.000000 -0.182024
# 8 -0.134733  0.207913 -0.078375  ...  0.000000 -0.203866  0.000000 -0.301327
# 9  0.182483  0.233087  0.000000  ...  0.263485  0.000000  0.200773  0.000000
#
#          26        27        28        29        30        31
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000 -0.395093
# 2 -0.320124  0.000000 -0.278211  0.306341 -0.862369 -0.356445
# 3 -0.294073  0.000000  0.247655 -0.301722  0.000000 -0.340614
# 4  0.000000  0.281949  0.278310 -0.269318  0.129511 -0.325354
# 5  0.000000  0.000000  0.000000  0.000000 -0.313087  0.000000
# 6  0.000000  0.000000  0.000000 -0.308136  0.000000  0.000000
# 7  0.000000  0.204898  0.171272 -0.127115 -0.301968  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9 -0.203758  0.000000  0.000000  0.113404 -0.073246 -0.300710
#
# [10 rows x 32 columns]
